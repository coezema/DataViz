# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use('seaborn-whitegrid')
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]
plt.scatter(X,Y)
plt.xlim(0,1000)
plt.ylim(0,100)

#scatter plot color
plt.scatter(X, Y, s=60, c='red', marker='^')

#change axes ranges
plt.xlim(0,1000)
plt.ylim(0,100)

#add title
plt.title('Relationship Between Temperature and Iced Coffee Sales')

#add x and y labels
plt.xlabel('Sold Coffee')
plt.ylabel('Temperature in Fahrenheit')

# %%
plt.show()

# %%
plt.style.use('seaborn-whitegrid')

# Create empty figure
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# set the x and y axis range
plt.xlim(0, 11)
plt.ylim(-2, 2)
plt.axis('tight')

#add title
plt.title('Plotting data using sin and cos')
# Out:
# Text(0.5, 1.0, 'Plotting data using sin and cos')

# %%
import pandas as pd
import seaborn as sns
plt.style.use('classic')
plt.style.use('seaborn-whitegrid')
# Create some data
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]],
size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
# Plot the data with seaborn
sns.distplot(data['x'])
sns.distplot(data['y']);

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %%
# used this instead code provided by book is deprecated
sns.kdeplot(data['x'], data['y']);

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='kde');

# %%
with sns.axes_style('white'):
    sns.jointplot("x", "y", data, kind='hex')

# %%
sns.pairplot(data);

# %%
import plotly.graph_objs as go
import plotly.offline as py
x = np.random.randn(2000)
y = np.random.randn(2000)
py.iplot([go.Histogram2dContour(x=x, y=y,
contours=dict (coloring='heatmap')),
go.Scatter(x=x, y=y, mode='markers',
marker=dict(color='white', size=3,
opacity=0.3))], show_link=False)
# Out:
# <div>
#
#
#             <div id="01f6b253-ceb0-4cac-8080-c43cd706dfd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("01f6b253-ceb0-4cac-8080-c43cd706dfd7")) {
#                     Plotly.newPlot(
#                         '01f6b253-ceb0-4cac-8080-c43cd706dfd7',
#                         [{"contours": {"coloring": "heatmap"}, "type": "histogram2dcontour", "x": [-0.9158491185189337, 0.3694062082240576, 0.20073111756702874, 1.670840349645725, -1.1049715435453582, -0.5667200352393477, 1.0238708314289793, 1.9349723320417942, 0.6529860531328704, 1.48887177753133, -0.9495227235314734, 1.5403596156231905, 0.18014761278611818, 0.19017062135969828, -0.31681450903442315, 0.11359992416918832, 1.1245283629377323, 0.17701986940110162, -0.06975783040984207, 1.4683855779062223, -0.12157140962059389, 0.737190577860603, -0.8426091955275462, 0.5570723174773929, 0.9981614738627229, -0.44443104655929716, 0.042932646757199704, 1.8065768373370612, 0.7972263124486968, -0.20201563475609863, 1.4285896494169328, 0.016065155750068155, 0.6604071711639893, 1.9412506816492328, -0.9741714270702817, -0.5171089630832176, 1.2437452636300452, 1.4868280813435026, 0.016098330920818017, 0.40598897733805706, -0.5922943488839028, -1.4309865559348847, -1.0949442450347893, 0.9239892258713626, 0.3112573890498433, 0.3592170156239164, 0.8233593156213
# %%
import plotly.offline as offline
import plotly.graph_objs as go
offline.plot({'data': [{'y': [14, 22, 30,
44]}],'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
# Out:
# 'temp-plot.html'

# %%
from plotly import __version__
print (__version__)
# Out:
# 4.5.2

# %%
import plotly.graph_objs as go
plot([go.Scatter(x=[95, 77, 84], y=[75, 67, 56])])
# Out:
# 'temp-plot.html'

# %%
df = pd.DataFrame(np.random.randn(200,6),index= pd.date_range('1/9/2009', periods=200), columns= list('ABCDEF'))
df.plot(figsize=(20, 10)).legend(bbox_to_anchor=(1, 1))

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb',
'March','April', 'May'])
df.plot.bar(figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May']) 
df.plot.bar(stacked=True, figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May']) 
df.plot.barh(stacked=True,figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.hist(bins= 20, figsize=(10,8)).legend 
bbox_to_anchor=(1.2, 1)

# %%
df=pd.DataFrame({'April':np.random.randn(1000)+1,'May':np.random.randn(1000),'June': np.random.randn(1000) - 1}, columns=['April','May', 'June'])
df.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022483D74248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022483E319C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000224827539C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022483ED5AC8>]],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.rand(20,5),
columns=['Jan','Feb','March','April', 'May'])
df.plot.box()

# %%
df = pd.DataFrame(np.random.rand(20,5),columns= ['Jan','Feb','March','April', 'May'])
df.plot.area(figsize=(6, 4)).legend(bbox_to_anchor=(1.3, 1))

# %%
df = pd.DataFrame(np.random.rand(20,5),columns= ['Jan','Feb','March','April', 'May'])
df.plot.scatter(x='Feb', y='Jan', title='Temperature over two months ')

# %%
salesMen = ['Ahmed', 'Omar', 'Ali', 'Ziad', 'Salwa', 'Lila']
Mobile_Sales = [2540, 1370, 1320, 2000, 2100, 2150]
TV_Sales = [2200, 1900, 2150, 1850, 1770, 2000]
df = pd.DataFrame()
df ['Name'] =salesMen
df ['Mobile_Sales'] = Mobile_Sales
df['TV_Sales']=TV_Sales
df.set_index("Name",drop=True,inplace=True)
df
# Out:
#        Mobile_Sales  TV_Sales
# Name
# Ahmed          2540      2200
# Omar           1370      1900
# Ali            1320      2150
# Ziad           2000      1850
# Salwa          2100      1770
# Lila           2150      2000

# %%
df.plot.bar( figsize=(20, 10), rot=0).legend(bbox_to_anchor=(1.1, 1)) 
plt.xlabel('Salesmen') 
plt.ylabel('Sales')
plt.title('Sales Volume for two salesmen in \nJanuary and April 2017')
plt.show()

# %%
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000224844B6F48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000022482901548>],
#       dtype=object)

# %%
df.plot.box()

# %%
df.plot.area(figsize=(6, 4)).legend(bbox_to_anchor=(1.3,1))

# %%
df.plot.bar(stacked=True, figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

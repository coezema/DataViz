# %%
import pandas as pd
import numpy as np
Location = "C:/Users/coezema/Desktop/Untitled Folder/datasets/gradedata.xlsx"
df = pd.read_excel(Location)

# %%
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                                address
# 1995              8567 Walnut Street , Piqua, OH 45356
# 1996                  Lynn, MA 01902, 66 Bridge Drive
# 1997       Loxahatchee, FL 33470, 8887 NE. Sugar Road
# 1998  8734 South Birch Hill Drive , Canfield, OH 44406
# 1999            21 Glen Ridge St. , Highland, IN 46322

# %% [markdown]
# ### Your  Turn
# <p>Can you create a random sample of 500 rows from that dataset?</p>

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#         fname      lname  gender  age  exercise  hours  grade  \
# 256     Rylee       Ward  female   18         2      9   88.4
# 1223  Georgia  Castaneda  female   14         3     10   78.4
# 1252   Declan     Macias    male   14         2     14   83.2
# 1754   Darrel       Wood  female   19         1     14   91.5
# 270   Forrest    Rollins    male   17         2     19   87.2
# ...       ...        ...     ...  ...       ...    ...    ...
# 50    Aladdin   Chambers    male   19         4     11   82.6
# 1653   Xavier      Moran    male   14         2      6   66.0
# 1115     Yoko     Hurley  female   15         4     12   84.2
# 775     Brody      Sharp    male   19         4     12   93.1
# 1429   Amanda    Tillman  female   18         2      6   78.6
#
#                                                 address
# 256            Halethorpe, MD 21227, 86 Andover Street
# 1223         8914 Edgefield Street , Cheshire, CT 06410
# ...

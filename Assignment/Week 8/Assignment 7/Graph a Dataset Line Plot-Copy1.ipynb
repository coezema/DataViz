# %% [markdown]
# ### Creating Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

names = ['Bob','Jessica','Mary','John','Mel']
grades = [76,83,77,78,95]
status = ['Senior','Senior','Junior','Junior','Senior']
GradeList = zip(names,grades,status)
df = pd.DataFrame(data = GradeList,
                  columns=['Names', 'Grades','Status'])
# %matplotlib inline
df.plot()

# %% [markdown]
# ### Your  Turn
#
# <p> Can you change the code to create a bar plot where the status is the label?</p>

# %%
df2 = df.set_index(df['Status'])
df2.plot( kind = 'bar')
